# %%
import pandas as pd

files = [
{"file": "bulk_rides"},
{"file": "map_cities"},
{"file":"map_cancellation_reasons"},
{"file":"map_payment_methods"},
{"file":"map_ride_statuses"},
{"file":"map_vehicle_makes"},
{"file":"map_vehicle_types"}
]

for file in files:

    url = f"https://uberchathudatalake.blob.core.windows.net/raw/ingestion/{file['file']}.json?sp=r&st=2026-04-03T10:16:31Z&se=2026-04-09T18:31:31Z&spr=https&sv=2024-11-04&sr=c&sig=4ws0pQHF9DVzsl82F%2BpMvjWYjEtrr8rZkG15RNngC9Q%3D"

    df = pd.read_json(url)
    df_spark = spark.createDataFrame(df)
    
    # Writing Data To the Bronze Layer
    df_spark.write.format("delta")\
            .mode("overwrite")\
            .option("overwriteSchema", "true")\
            .saveAsTable(f"uber.bronze.{file['file']}")

# %%
# %sql
SELECT * FROM uber.bronze.rides_raw
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th><th>topic</th><th>partition</th><th>offset</th><th>timestamp</th><th>timestampType</th><th>rides</th></tr></thead><tbody><tr><td>null</td><td>...</td><td>ubertopic</td><td>0</td><td>0</td><td>2026-04-02T03:40:45.415Z</td><td>0</td><td>{"ride_id": "beaef021-1dd4-4a79-9adb-8740f02f7856", "confirmation_number": "Ef5-4641-Mo22", "passenger_id": "8e8a7eaa-4c0b-48c6-a255-ea80513d1d6d", "driver_id": "50576940-1c5b-401a-b8ef-bf1e51ec0a46", "vehicle_id": "c69d1fae-e06f-4bb0-8c0c-3897cb56e119", "pickup_location_id": "28b79822-8650-4397-a655-a00d23a5aa6b", "dropoff_location_id": "0ed23eb8-c029-41e6-ba9f-743c708f065e", "vehicle_type_id": 4, "vehicle_make_id": 1, "payment_method_id": 4, "ride_status_id": 2, "pickup_city_id": 8, "dropoff_city_id": 3, "cancellation_reason_id": 3, "passenger_name": "Patrick Ray III", "passenger_email": "jasonmills@example.net", "passenger_phone": "757.290.3296x3513", "driver_name": "Brian Rogers", "driver_rating": 4.63, "driver_phone": "+1-851-617-0871", "driver_license": "UL-QVg-7632684", "vehicle_model": "Son", "vehicle_color": "Silver", "license_plate": "qsd-6413", "pickup_address": "142 Martinez Gardens Apt. 181, New Alisha, OR 45157", "pickup_latitude": -32.492306, "pickup_longitude": -89.810337, "dropoff_address": "049 Hughes Village Suite 367, Johnsonfurt, NJ 48872", "dropoff_latitude": -59.829065, "dropoff_longitude": 124.761907, "distance_miles": 27.64, "duration_minutes": 51, "booking_timestamp": "2026-03-05T16:05:40.388166", "pickup_timestamp": "2026-03-05T16:10:40.388166", "dropoff_timestamp": "2026-03-05T17:01:40.388166", "base_fare": 2.5, "distance_fare": 48.37, "time_fare": 17.85, "surge_multiplier": 1.2, "subtotal": 82.46, "tip_amount": 2.81, "total_fare": 85.27, "rating": null}</td></tr><tr><td>null</td><td>...</td><td>ubertopic</td><td>0</td><td>1</td><td>2026-04-02T03:49:12.806Z</td><td>0</td><td>{"ride_id": "ee2ad28f-6ae2-4f4b-9ccc-94f35897dbdb", "confirmation_number": "kS9-9943-Si98", "passenger_id": "b993d290-110d-4421-90f1-a2b7441b477f", "driver_id": "da41faf2-fefb-40e2-8226-ddcc35a83f60", "vehicle_id": "f823ff59-1398-41ea-9f69-d5611bcdc6e7", "pickup_location_id": "4ad33a25-3e2b-40c6-8856-2fe0e141e3f3", "dropoff_location_id": "e56bd9bd-5f25-4a18-a1d7-feb5a4e23ea6", "vehicle_type_id": 3, "vehicle_make_id": 7, "payment_method_id": 2, "ride_status_id": 1, "pickup_city_id": 8, "dropoff_city_id": 10, "cancellation_reason_id": 4, "passenger_name": "Rachel Gibson", "passenger_email": "marcia56@example.org", "passenger_phone": "229-862-7182", "driver_name": "Brooke Payne", "driver_rating": 4.96, "driver_phone": "001-608-603-1656x8678", "driver_license": "Xj-Bte-6848594", "vehicle_model": "Believe", "vehicle_color": "Blue", "license_plate": "aeL-2187", "pickup_address": "7131 Jim Square, Lake Dennisport, VA 49740", "pickup_latitude": 6.232627, "pickup_longitude": 142.666859, "dropoff_address": "9102 Kenneth Curve Apt. 607, New Julie, CA 50714", "dropoff_latitude": 21.650399, "dropoff_longitude": -39.236804, "distance_miles": 33.7, "duration_minutes": 29, "booking_timestamp": "2026-04-01T12:10:07.046156", "pickup_timestamp": "2026-04-01T12:19:07.046156", "dropoff_timestamp": "2026-04-01T12:48:07.046156", "base_fare": 2.5, "distance_fare": 58.98, "time_fare": 10.15, "surge_multiplier": 1.71, "subtotal": 122.49, "tip_amount": 3, "total_fare": 125.49, "rating": 5}</td></tr><tr><td>null</td><td>...</td><td>ubertopic</td><td>0</td><td>2</td><td>2026-04-02T03:57:39.030Z</td><td>0</td><td>{"ride_id": "871e6a25-d209-4460-b6e9-de0588ff3778", "confirmation_number": "Ho9-4644-to42", "passenger_id": "480d2a0c-b860-44e0-9ff9-88c52ed85b77", "driver_id": "6b5172ab-e89a-497f-86f5-a5af32965df3", "vehicle_id": "db164823-4fa2-41b5-8dca-ba90ff353ab5", "pickup_location_id": "a846115a-cbed-46ef-9e6b-6eb63c23e404", "dropoff_location_id": "278fbb74-1e81-4f79-aebd-d7328cb59b5d", "ve ...
